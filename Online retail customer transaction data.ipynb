# %%
import pandas as pd

# %%
da = pd.read_excel("C:\\Users\\ahmed\\Documents\\Online_retail_customer_transaction_data.xlsx")

# %%
da
# Out:
#        index InvoiceNo StockCode                          Description  \
# 0          0    536365     85123   WHITE HANGING HEART T-LIGHT HOLDER
# 1          1    536365     71053                  WHITE METAL LANTERN
# 2          2    536365     84406       CREAM CUPID HEARTS COAT HANGER
# 3          3    536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE
# 4          4    536365     84029       RED WOOLLY HOTTIE WHITE HEART.
# ...      ...       ...       ...                                  ...
# 9996    9996    537224     22623        BOX OF VINTAGE JIGSAW BLOCKS
# 9997    9997    537224     21363              HOME SMALL WOOD LETTERS
# 9998    9998    537224     21556         CERAMIC STRAWBERRY MONEY BOX
# 9999    9999    537224     22497      SET OF 2 TINS VINTAGE BATHROOM
# 10000  10000    537224     22500     SET OF 2 TINS JARDIN DE PROVENCE
#
#        Quantity         InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
da.describe()
# Out:
#               index      Quantity                    InvoiceDate  \
# count  10001.000000  10001.000000                          10001
# mean    5000.000000      7.828017  2010-03-04 01:46:22.971703040
# min        0.000000  -9360.000000            2010-01-12 08:26:00
# 25%     2500.000000      1.000000            2010-01-12 17:06:00
# 50%     5000.000000      2.000000            2010-02-12 18:08:00
# 75%     7500.000000      8.000000            2010-05-12 10:45:00
# max    10000.000000   2880.000000            2010-05-12 16:24:00
# std     2887.184355    104.317217                            NaN
#
#           UnitPrice    CustomerID
# count  10001.000000   7710.000000
# mean       3.837523  15615.145914
# min        0.000000  12395.000000
# 25%        1.250000  14388.000000
# 50%        2.510000  15605.000000
# 75%        4.210000  17228.000000
# max      887.520000  18239.000000
# std       14.309437   1756.646939

# %%
da.columns
# Out:
# Index(['index', 'InvoiceNo', 'StockCode', 'Description', 'Quantity',
#        'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
da["Description"] = da["Description"].fillna("No Description")

# %%
da.dropna(axis = 1)
# Out:
#        index InvoiceNo StockCode                          Description  \
# 0          0    536365     85123   WHITE HANGING HEART T-LIGHT HOLDER
# 1          1    536365     71053                  WHITE METAL LANTERN
# 2          2    536365     84406       CREAM CUPID HEARTS COAT HANGER
# 3          3    536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE
# 4          4    536365     84029       RED WOOLLY HOTTIE WHITE HEART.
# ...      ...       ...       ...                                  ...
# 9996    9996    537224     22623        BOX OF VINTAGE JIGSAW BLOCKS
# 9997    9997    537224     21363              HOME SMALL WOOD LETTERS
# 9998    9998    537224     21556         CERAMIC STRAWBERRY MONEY BOX
# 9999    9999    537224     22497      SET OF 2 TINS VINTAGE BATHROOM
# 10000  10000    537224     22500     SET OF 2 TINS JARDIN DE PROVENCE
#
#        Quantity         InvoiceDate  UnitPrice         Country
# 0             6 2010-01-12 08:26:00       2.55  United Kingdom
# ...

# %%
da.isna().sum()
# Out:
# index          0
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
da["CustomerID"] = da["CustomerID"].fillna(0)

# %%
da.isna().sum()
# Out:
# index          0
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
da.to_excel("C:\\Users\\ahmed\\Documents\\cleaned_data.xlsx", index=False)

# %%
da.loc[da["UnitPrice"] == 0]
# Out:
# Empty DataFrame
# Columns: [index, InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
da["UnitPrice"].nunique()
# Out:
# 154

# %%
da.loc[da["UnitPrice"] == 0]
# Out:
#       index InvoiceNo StockCode                   Description  Quantity  \
# 622     622    536414     22139                No Description        56
# 1970   1970    536545     21134                No Description         1
# 1971   1971    536546     22145                No Description         1
# 1972   1972    536547     37509                No Description         1
# 1987   1987    536549    85226A                No Description         1
# 1988   1988    536550     85044                No Description         1
# 2024   2024    536552     20950                No Description         1
# 2025   2025    536553     37461                No Description         3
# 2026   2026    536554     84670                No Description        23
# 2406   2406    536589     21777                No Description       -10
# 4347   4347    536764    84952C                No Description       -38
# 4348   4348    536765    84952C                No Description        19
# ...

# %%
print("before:", da.shape)
# Out:
# After: (10001, 9)

# %%
da = da[da["UnitPrice"] != 0]

# %%
print("After:", da.shape)
# Out:
# After: (9955, 9)

# %%
da.loc[da["UnitPrice"] == 0]
# Out:
# Empty DataFrame
# Columns: [index, InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
da.loc[da["Quantity"] <= 0]
# Out:
#       index InvoiceNo StockCode                         Description  Quantity  \
# 141     141   C536379         D                            Discount        -1
# 154     154   C536383    35004C     SET OF 3 COLOURED  FLYING DUCKS        -1
# 235     235   C536391     22556      PLASTERS IN TIN CIRCUS PARADE        -12
# 236     236   C536391     21984    PACK OF 12 PINK PAISLEY TISSUES        -24
# 237     237   C536391     21983    PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...     ...       ...       ...                                 ...       ...
# 8685   8685   C537143     20685               DOORMAT RED RETROSPOT        -1
# 8952   8952   C537157     35953  FOLKART STAR CHRISTMAS DECORATIONS       -24
# 9038   9038   C537164         D                            Discount        -1
# 9493   9493   C537203     37449  CERAMIC CAKE STAND + HANGING CAKES        -1
# 9494   9494   C537203     21424         WOODLAND STORAGE BOX LARGE         -1
#
# ...

# %%
da["InvoiceDate"].tail(100)
# Out:
# 9901    2010-05-12 16:00:00
# 9902    2010-05-12 16:10:00
# 9903    2010-05-12 16:10:00
# 9904    2010-05-12 16:10:00
# 9905    2010-05-12 16:10:00
#                 ...
# 9996    2010-05-12 16:24:00
# 9997    2010-05-12 16:24:00
# 9998    2010-05-12 16:24:00
# 9999    2010-05-12 16:24:00
# 10000   2010-05-12 16:24:00
# Name: InvoiceDate, Length: 100, dtype: datetime64[ns]

# %%
da.loc[:, 'date'] = da['InvoiceDate'].dt.date

# %%
da
# Out:
#        index InvoiceNo StockCode                          Description  \
# 0          0    536365     85123   WHITE HANGING HEART T-LIGHT HOLDER
# 1          1    536365     71053                  WHITE METAL LANTERN
# 2          2    536365     84406       CREAM CUPID HEARTS COAT HANGER
# 3          3    536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE
# 4          4    536365     84029       RED WOOLLY HOTTIE WHITE HEART.
# ...      ...       ...       ...                                  ...
# 9996    9996    537224     22623        BOX OF VINTAGE JIGSAW BLOCKS
# 9997    9997    537224     21363              HOME SMALL WOOD LETTERS
# 9998    9998    537224     21556         CERAMIC STRAWBERRY MONEY BOX
# 9999    9999    537224     22497      SET OF 2 TINS VINTAGE BATHROOM
# 10000  10000    537224     22500     SET OF 2 TINS JARDIN DE PROVENCE
#
#        Quantity         InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
da.loc[:, 'Time'] = da['InvoiceDate'].dt.time

# %%
da
# Out:
#        index InvoiceNo StockCode                          Description  \
# 0          0    536365     85123   WHITE HANGING HEART T-LIGHT HOLDER
# 1          1    536365     71053                  WHITE METAL LANTERN
# 2          2    536365     84406       CREAM CUPID HEARTS COAT HANGER
# 3          3    536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE
# 4          4    536365     84029       RED WOOLLY HOTTIE WHITE HEART.
# ...      ...       ...       ...                                  ...
# 9996    9996    537224     22623        BOX OF VINTAGE JIGSAW BLOCKS
# 9997    9997    537224     21363              HOME SMALL WOOD LETTERS
# 9998    9998    537224     21556         CERAMIC STRAWBERRY MONEY BOX
# 9999    9999    537224     22497      SET OF 2 TINS VINTAGE BATHROOM
# 10000  10000    537224     22500     SET OF 2 TINS JARDIN DE PROVENCE
#
#        Quantity         InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
da.to_excel("C:\\Users\\ahmed\\Documents\\cleaned_data2.xlsx")

# %%
df = pd.read_excel("C:\\Users\\ahmed\\Documents\\cleaned_data2.xlsx")

# %%
df
# Out:
#       Unnamed: 0  index InvoiceNo StockCode  \
# 0              0      0    536365     85123
# 1              1      1    536365     71053
# 2              2      2    536365     84406
# 3              3      3    536365     84029
# 4              4      4    536365     84029
# ...          ...    ...       ...       ...
# 9950        9996   9996    537224     22623
# 9951        9997   9997    537224     21363
# 9952        9998   9998    537224     21556
# 9953        9999   9999    537224     22497
# 9954       10000  10000    537224     22500
#
#                               Description  Quantity         InvoiceDate  \
# 0      WHITE HANGING HEART T-LIGHT HOLDER         6 2010-01-12 08:26:00
# 1                     WHITE METAL LANTERN         6 2010-01-12 08:26:00
# 2          CREAM CUPID HEARTS COAT HANGER         8 2010-01-12 08:26:00
# 3     KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-01-12 08:26:00
# ...

# %%
df.loc[:,"Days"] = df["InvoiceDate"].dt.day

# %%
df.loc[:,"Year"] = df["InvoiceDate"].dt.year

# %%
df.loc[:,"DayOfWeek"] = df["InvoiceDate"].dt.dayofweek

# %%
df.loc[:,"Hour"] = df["InvoiceDate"].dt.hour

# %%
df.loc[:,"Minute"] = df["InvoiceDate"].dt.minute

# %%
df
# Out:
#       Unnamed: 0  index InvoiceNo StockCode  \
# 0              0      0    536365     85123
# 1              1      1    536365     71053
# 2              2      2    536365     84406
# 3              3      3    536365     84029
# 4              4      4    536365     84029
# ...          ...    ...       ...       ...
# 9950        9996   9996    537224     22623
# 9951        9997   9997    537224     21363
# 9952        9998   9998    537224     21556
# 9953        9999   9999    537224     22497
# 9954       10000  10000    537224     22500
#
#                               Description  Quantity         InvoiceDate  \
# 0      WHITE HANGING HEART T-LIGHT HOLDER         6 2010-01-12 08:26:00
# 1                     WHITE METAL LANTERN         6 2010-01-12 08:26:00
# 2          CREAM CUPID HEARTS COAT HANGER         8 2010-01-12 08:26:00
# 3     KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-01-12 08:26:00
# ...

# %%
def categorize_time(Hour):
    if 5 <= Hour < 12:
        return 'Morning'
    elif 12 <= Hour < 17:
        return 'Afternoon'
    elif 17 <= Hour < 21:
        return 'Evening'
    else:
        return 'Night'

df["TimeOfDay"] = df["Hour"].apply(categorize_time)

# %%
df
# Out:
#       Unnamed: 0  index InvoiceNo StockCode  \
# 0              0      0    536365     85123
# 1              1      1    536365     71053
# 2              2      2    536365     84406
# 3              3      3    536365     84029
# 4              4      4    536365     84029
# ...          ...    ...       ...       ...
# 9950        9996   9996    537224     22623
# 9951        9997   9997    537224     21363
# 9952        9998   9998    537224     21556
# 9953        9999   9999    537224     22497
# 9954       10000  10000    537224     22500
#
#                               Description  Quantity         InvoiceDate  \
# 0      WHITE HANGING HEART T-LIGHT HOLDER         6 2010-01-12 08:26:00
# 1                     WHITE METAL LANTERN         6 2010-01-12 08:26:00
# 2          CREAM CUPID HEARTS COAT HANGER         8 2010-01-12 08:26:00
# 3     KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-01-12 08:26:00
# ...

# %%
df.drop("Unnamed: 0",axis = 1, inplace = True)

# %%
df.drop("date",axis = 1, inplace = True)

# %%
df
# Out:
#       index InvoiceNo StockCode                          Description  \
# 0         0    536365     85123   WHITE HANGING HEART T-LIGHT HOLDER
# 1         1    536365     71053                  WHITE METAL LANTERN
# 2         2    536365     84406       CREAM CUPID HEARTS COAT HANGER
# 3         3    536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE
# 4         4    536365     84029       RED WOOLLY HOTTIE WHITE HEART.
# ...     ...       ...       ...                                  ...
# 9950   9996    537224     22623        BOX OF VINTAGE JIGSAW BLOCKS
# 9951   9997    537224     21363              HOME SMALL WOOD LETTERS
# 9952   9998    537224     21556         CERAMIC STRAWBERRY MONEY BOX
# 9953   9999    537224     22497      SET OF 2 TINS VINTAGE BATHROOM
# 9954  10000    537224     22500     SET OF 2 TINS JARDIN DE PROVENCE
#
#       Quantity         InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
df["UnitPrice"].max()
# Out:
# 887.52

# %%
Q1 = df['UnitPrice'].quantile(0.25)
Q3 = df['UnitPrice'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(lower_bound,"aaaaaaaaaaa",upper_bound)
# Identify outliers
outliers = df[(df['UnitPrice'] < lower_bound) | (df['UnitPrice'] > upper_bound)]
# Out:
# -3.1899999999999995 aaaaaaaaaaa 8.649999999999999

# %%
outliers
# Out:
#       index InvoiceNo StockCode                      Description  Quantity  \
# 16       16    536367     22622   BOX OF VINTAGE ALPHABET BLOCKS         2
# 45       45    536370      POST                          POSTAGE         3
# 65       65    536374     21258       VICTORIAN SEWING BOX LARGE        32
# 141     141   C536379         D                         Discount        -1
# 151     151    536382     22839  3 TIER CAKE TIN GREEN AND CREAM         2
# ...     ...       ...       ...                              ...       ...
# 9929   9975    537224     22768       FAMILY PHOTO FRAME CORNICE         2
# 9933   9979    537224     22830        UTILTY CABINET WITH HOOKS         1
# 9947   9993    537224     22767      TRIPLE PHOTO FRAME CORNICE          2
# 9948   9994    537224     21361         LOVE LARGE WOOD LETTERS          1
# 9949   9995    537224     22622   BOX OF VINTAGE ALPHABET BLOCKS         2
#
# ...

# %%
df.to_excel("C:\\Users\\ahmed\\Documents\\Online_retail_customer_transactioncleaned_data.xlsx")

# %%
df =pd.read_excel("C:\\Users\\ahmed\\Documents\\data\\Online_retail_customer_transactioncleaned_data.xlsx")

# %%
df
# Out:
#       Unnamed: 0  index InvoiceNo StockCode  \
# 0              0      0    536365     85123
# 1              1      1    536365     71053
# 2              2      2    536365     84406
# 3              3      3    536365     84029
# 4              4      4    536365     84029
# ...          ...    ...       ...       ...
# 9950        9950   9996    537224     22623
# 9951        9951   9997    537224     21363
# 9952        9952   9998    537224     21556
# 9953        9953   9999    537224     22497
# 9954        9954  10000    537224     22500
#
#                               Description  Quantity         InvoiceDate  \
# 0      WHITE HANGING HEART T-LIGHT HOLDER         6 2010-01-12 08:26:00
# 1                     WHITE METAL LANTERN         6 2010-01-12 08:26:00
# 2          CREAM CUPID HEARTS COAT HANGER         8 2010-01-12 08:26:00
# 3     KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-01-12 08:26:00
# ...

# %%
df.loc[df["Quantity"] <= 0]
# Out:
#       Unnamed: 0  index InvoiceNo StockCode  \
# 141          141    141   C536379         D
# 154          154    154   C536383    35004C
# 235          235    235   C536391     22556
# 236          236    236   C536391     21984
# 237          237    237   C536391     21983
# ...          ...    ...       ...       ...
# 8640        8640   8685   C537143     20685
# 8907        8907   8952   C537157     35953
# 8993        8993   9038   C537164         D
# 9447        9447   9493   C537203     37449
# 9448        9448   9494   C537203     21424
#
#                              Description  Quantity         InvoiceDate  \
# 141                             Discount        -1 2010-01-12 09:41:00
# 154      SET OF 3 COLOURED  FLYING DUCKS        -1 2010-01-12 09:49:00
# 235       PLASTERS IN TIN CIRCUS PARADE        -12 2010-01-12 10:24:00
# 236     PACK OF 12 PINK PAISLEY TISSUES        -24 2010-01-12 10:24:00
# 237     PACK OF 12 BLUE PAISLEY TISSUES        -24 2010-01-12 10:24:00
# ...

# %%
df = df[df['Quantity'] >= 0]

# %%
# Out:
#       Unnamed: 0  index InvoiceNo StockCode  \
# 0              0      0    536365     85123
# 1              1      1    536365     71053
# 2              2      2    536365     84406
# 3              3      3    536365     84029
# 4              4      4    536365     84029
# ...          ...    ...       ...       ...
# 9950        9950   9996    537224     22623
# 9951        9951   9997    537224     21363
# 9952        9952   9998    537224     21556
# 9953        9953   9999    537224     22497
# 9954        9954  10000    537224     22500
#
#                               Description  Quantity         InvoiceDate  \
# 0      WHITE HANGING HEART T-LIGHT HOLDER         6 2010-01-12 08:26:00
# 1                     WHITE METAL LANTERN         6 2010-01-12 08:26:00
# 2          CREAM CUPID HEARTS COAT HANGER         8 2010-01-12 08:26:00
# 3     KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-01-12 08:26:00
# ...

# %%
df.loc[:,"TotalPrice"] = df['Quantity'] * df['UnitPrice']

# %%
df
# Out:
#       index InvoiceNo StockCode                          Description  \
# 0         0    536365     85123   WHITE HANGING HEART T-LIGHT HOLDER
# 1         1    536365     71053                  WHITE METAL LANTERN
# 2         2    536365     84406       CREAM CUPID HEARTS COAT HANGER
# 3         3    536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE
# 4         4    536365     84029       RED WOOLLY HOTTIE WHITE HEART.
# ...     ...       ...       ...                                  ...
# 9950   9996    537224     22623        BOX OF VINTAGE JIGSAW BLOCKS
# 9951   9997    537224     21363              HOME SMALL WOOD LETTERS
# 9952   9998    537224     21556         CERAMIC STRAWBERRY MONEY BOX
# 9953   9999    537224     22497      SET OF 2 TINS VINTAGE BATHROOM
# 9954  10000    537224     22500     SET OF 2 TINS JARDIN DE PROVENCE
#
#       Quantity         InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
df
# Out:
#       index InvoiceNo StockCode                          Description  \
# 0         0    536365     85123   WHITE HANGING HEART T-LIGHT HOLDER
# 1         1    536365     71053                  WHITE METAL LANTERN
# 2         2    536365     84406       CREAM CUPID HEARTS COAT HANGER
# 3         3    536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE
# 4         4    536365     84029       RED WOOLLY HOTTIE WHITE HEART.
# ...     ...       ...       ...                                  ...
# 9950   9996    537224     22623        BOX OF VINTAGE JIGSAW BLOCKS
# 9951   9997    537224     21363              HOME SMALL WOOD LETTERS
# 9952   9998    537224     21556         CERAMIC STRAWBERRY MONEY BOX
# 9953   9999    537224     22497      SET OF 2 TINS VINTAGE BATHROOM
# 9954  10000    537224     22500     SET OF 2 TINS JARDIN DE PROVENCE
#
#       Quantity         InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
df.to_excel("C:\\Users\\ahmed\\Documents\\Online_retail_customer_transactioncleaned_data112.xlsx")
